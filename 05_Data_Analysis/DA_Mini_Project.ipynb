# %% [markdown]
# # DA Mini Project
# * 주제 : 온라인 학습 플랫폼 사용자 행동 패턴 분석
# * 개요 :
# ```
# 이번 프로젝트는 학습 서비스를 이용하는 독자들 중 누가 서비스 구독을 연장할지 예측하기 위한 사전 파악에 초점을 맞추고 있습니다. 우리의 목표는 유저들의 학습 습관, 선호도, 이용 행태 등 다양한 측면을 면밀히 분석하는 것입니다.
#
#
# 이를 위해, 우리는 유저들의 학습 패턴, 서비스 이용 시간, 콘텐츠에 대한 반응, 그리고 이들이 얼마나 자주 서비스를 이용하는지 등 다양한 데이터를 수집하고 분석할 계획입니다. 이 데이터는 유저들이 서비스에 얼마나 만족하고 있는지, 어떤 요소들이 그들의 구독 결정에 영향을 미치는지 이해하는 데 중요한 역할을 할 것입니다.
# ```
# * 데이터셋 : mini.csv
#     * 메타데이터
#         * user_id: 사용자의 고유 식별자
#         * subscription_duration: 사용자가 서비스에 가입한 기간 (월)
#         * recent_login_time: 사용자가 마지막으로 로그인한 시간 (일)
#         * average_login_time:  사용자의 일반적인 로그인 시간
#         * average_time_per_learning_session: 각 학습 세션에 소요된 평균 시간 (분)
#         * monthly_active_learning_days: 월간 활동적인 학습 일수
#         * total_completed_courses: 완료한 총 코스 수
#         * recent_learning_achievement: 최근 학습 성취도
#         * abandoned_learning_sessions: 중단된 학습 세션 수
#         * community_engagement_level: 커뮤니티 참여도
#         * preferred_difficulty_level: 선호하는 난이도
#         * subscription_type: 구독 유형
#         * customer_inquiry_history: 고객 문의 이력
#         * payment_pattern : 사용자의 지난 3개월 간의 결제 패턴을 10진수로 표현한 값.
#           - 7: 3개월 모두 결제함
#           - 6: 첫 2개월은 결제했으나 마지막 달에는 결제하지 않음
#           - 5: 첫 달과 마지막 달에 결제함
#           - 4: 첫 달에만 결제함
#           - 3: 마지막 2개월에 결제함
#           - 2: 가운데 달에만 결제함
#           - 1: 마지막 달에만 결제함
#           - 0: 3개월 동안 결제하지 않음
#         * target: 사용자가 다음 달에도 구독을 계속할지 (1) 또는 취소할지 (0)를 나타냄

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# 데이터 불러오기

data = pd.read_csv('data/1.csv',encoding='cp949', sep=',')

# 독립변수와 종속변수 선택
X = data[['GDP', '사회적지지', '건강수명', '자유', '관용', '부패인식']]
y = data['점수']

# 회귀모델 학습
model = LinearRegression()
model.fit(X, y)

# 회귀분석 통계량 계산
y_pred = model.predict(X)
r_squared = r2_score(y, y_pred)
adjusted_r_squared = 1 - (1 - r_squared) * (len(y) - 1) / (len(y) - X.shape[1] - 1)
standard_error = (sum((y - y_pred) ** 2) / (len(y) - X.shape[1] - 1)) ** 0.5

# 결과 출력
print(f"다중 상관계수 (R): {(r_squared ** 0.5):.3f}")
print(f"결정계수 (R-squared): {r_squared:.3f}")
print(f"조정된 결정계수 (Adjusted R-squared): {adjusted_r_squared:.3f}")
print(f"표준 오차 (Standard error): {standard_error:.3f}")
print(f"관측수 (Number of observations): {len(y)}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 10
#       7 data = pd.read_csv('data/1.csv',encoding='cp949', sep=',')
#       9 # 독립변수와 종속변수 선택
# ---> 10 X = data[['GDP', '사회적지지', '건강수명', '자유', '관용', '부패인식']]
#      11 y = data['점수']
#      13 # 회귀모델 학습
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# 데이터 불러오기
data = pd.read_csv('data/1.csv',encoding='cp949', sep=',')

# 독립변수와 종속변수 선택
X = data[['GDP', '사회적지지', '건강수명', '자유', '관용', '부패인식']]
y = data['점수']

# 회귀모델 학습
model = LinearRegression()
model.fit(X, y)

# 회귀분석 통계량 계산
y_pred = model.predict(X)
r_squared = r2_score(y, y_pred)
adjusted_r_squared = 1 - (1 - r_squared) * (len(y) - 1) / (len(y) - X.shape[1] - 1)
standard_error = (sum((y - y_pred) ** 2) / (len(y) - X.shape[1] - 1)) ** 0.5

# 결과 출력
print(f"다중 상관계수 (R): {(r_squared ** 0.5):.3f}")
print(f"결정계수 (R-squared): {r_squared:.3f}")
print(f"조정된 결정계수 (Adjusted R-squared): {adjusted_r_squared:.3f}")
print(f"표준 오차 (Standard error): {standard_error:.3f}")
print(f"관측수 (Number of observations): {len(y)}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 9
#       6 data = pd.read_csv('data/1.csv',encoding='cp949', sep=',')
#       8 # 독립변수와 종속변수 선택
# ----> 9 X = data[['GDP', '사회적지지', '건강수명', '자유', '관용', '부패인식']]
#      10 y = data['점수']
#      12 # 회귀모델 학습
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of        년도           국가                               지역  행복 점수  1인당 GDP  \
# 0    2015  Afghanistan                    Southern Asia  3.575  0.31982
# 1    2015      Albania       Central and Eastern Europe  4.959  0.87867
# 2    2015      Algeria  Middle East and Northern Africa  5.605  0.93929
# 3    2015       Angola               Sub-Saharan Africa  4.033  0.75778
# 4    2015    Argentina      Latin America and Caribbean  6.574  1.05351
# ..    ...          ...                              ...    ...      ...
# 756  2019    Venezuela      Latin America and Caribbean  4.707  0.96000
# 757  2019      Vietnam                Southeastern Asia  5.175  0.74100
# 758  2019        Yemen  Middle East and Northern Africa  3.380  0.28700
# 759  2019       Zambia               Sub-Saharan Africa  4.107  0.57800
# 760  2019     Zimbabwe               Sub-Saharan Africa  3.663  0.36600
#
#           가족       건강       자유
# 0    0.30285  0.30335  0.23414
# ...

# %%
import pandas as pd
import numpy as np
from scipy.stats import pearsonr
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# 데이터 불러오기
data = pd.read_csv('data/1.csv',encoding='cp949', sep=',')

# 기술통계량
print("기술통계량:")
print(data.describe())

# 상관관계 분석
print("\n상관관계 분석:")
corr_matrix = data.corr()
print(corr_matrix)

# 상관관계 히트맵
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# 회귀분석
X = data[['GDP', '사회적지지', '건강수명', '자유', '관용', '부패인식']]
y = data['점수']

model = LinearRegression()
model.fit(X, y)

print("\n회귀분석:")
print(f"절편: {model.intercept_:.3f}")
print(f"회귀계수: {model.coef_}")

y_pred = model.predict(X)
r_squared = r2_score(y, y_pred)
adjusted_r_squared = 1 - (1 - r_squared) * (len(y) - 1) / (len(y) - X.shape[1] - 1)
standard_error = (sum((y - y_pred) ** 2) / (len(y) - X.shape[1] - 1)) ** 0.5

print(f"\n다중 상관계수 (R): {(r_squared ** 0.5):.3f}")
print(f"결정계수 (R-squared): {r_squared:.3f}")
print(f"조정된 결정계수 (Adjusted R-squared): {adjusted_r_squared:.3f}")
print(f"표준 오차 (Standard error): {standard_error:.3f}")
print(f"관측수 (Number of observations): {len(y)}")

# 연도별 평균 행복 점수
print("\n연도별 평균 행복 점수:")
print(data.groupby('연도')['점수'].mean())

# 지역별 평균 행복 점수
print("\n지역별 평균 행복 점수:")
print(data.groupby('지역')['점수'].mean())
# Out:
# 기술통계량:
#                 년도       행복 점수     1인당 GDP          가족          건강          자유
# count   761.000000  761.000000  761.000000  761.000000  761.000000  761.000000
# mean   2016.985545    5.399720    0.923125    1.081875    0.617625    0.412008
# std       1.411812    1.124113    0.407512    0.331185    0.247914    0.151076
# min    2015.000000    2.693000    0.000000    0.000000    0.000000    0.000000
# 25%    2016.000000    4.514000    0.619000    0.870701    0.454000    0.311000
# 50%    2017.000000    5.358000    0.989000    1.129624    0.653133    0.431000
# 75%    2018.000000    6.199000    1.244610    1.335000    0.809910    0.531000
# max    2019.000000    7.769000    2.096000    1.644000    1.141000    0.724000
#
# 상관관계 분석:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 16
#      14 # 상관관계 분석
#      15 print("\n상관관계 분석:")
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# 데이터 불러오기
data = pd.read_csv('data/1.csv',encoding='cp949', sep=',')

# 독립변수와 종속변수 선택
X = data[['1인당GDP', '가족', '건강', '자유']]
y = data['점수']

# 회귀모델 학습
model = LinearRegression()
model.fit(X, y)

# 잔차 계산
residuals = y - model.predict(X)

# 잔차도 시각화
fig, axs = plt.subplots(2, 2, figsize=(12, 10))
fig.suptitle('Residual Plots')

axs[0, 0].scatter(X['1인당GDP'], residuals)
axs[0, 0].set_xlabel('GDP per capita')
axs[0, 0].set_ylabel('Residuals')
axs[0, 0].axhline(y=0, color='r', linestyle='-')

axs[0, 1].scatter(X['가족'], residuals)
axs[0, 1].set_xlabel('Family')
axs[0, 1].set_ylabel('Residuals')
axs[0, 1].axhline(y=0, color='r', linestyle='-')

axs[1, 0].scatter(X['건강'], residuals)
axs[1, 0].set_xlabel('Health')
axs[1, 0].set_ylabel('Residuals')
axs[1, 0].axhline(y=0, color='r', linestyle='-')

axs[1, 1].scatter(X['자유'], residuals)
axs[1, 1].set_xlabel('Freedom')
axs[1, 1].set_ylabel('Residuals')
axs[1, 1].axhline(y=0, color='r', linestyle='-')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 9
#       6 data = pd.read_csv('data/1.csv',encoding='cp949', sep=',')
#       8 # 독립변수와 종속변수 선택
# ----> 9 X = data[['1인당GDP', '가족', '건강', '자유']]
#      10 y = data['점수']
#      12 # 회귀모델 학습
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
# ...
